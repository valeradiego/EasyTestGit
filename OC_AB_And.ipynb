# %% [markdown]
# <a href="https://colab.research.google.com/github/valeradiego/EasyTestGit/blob/main/OC_AB_And.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Lee las hojas aqui!!

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from google.colab import files
from matplotlib import colors

# Specify the path to your .DAT file in Google Drive

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv('AB And O-C.csv', sep=';')

# Mostrar las primeras filas del DataFrame
print(df.head())
# Out:
#    EPOCH   O-C       HJDmin Unnamed: 3 P/S        METHOD OBSERVER  \
# 0      0     0  161,039,250          s  pg  Binnendijk L      NaN
# 1   7776  -190  186,845,120          p  pg  Binnendijk L      NaN
# 2   8617  -170  189,636,330          p  pg  Binnendijk L      NaN
# 3  26083  -702  247,603,600          p  pg    Guthnick P      NaN
# 4  27638  -737  252,764,445          p  pg    Jordan F C      NaN
#
#                   Unnamed: 7 SOC,BULLETIN,S2,
# 0            I,0190,I,0190,,              NaN
# 1            I,0190,I,0190,,              NaN
# 2            I,0190,I,0190,,              NaN
# 3   I,0190,I,0190,KVBB 4.26,              NaN
# 4  I,0190,I,0190,PALL 7.136,              NaN

# %%
plt.scatter(df['EPOCH'], df['O-C'])
plt.axhline(y=0, color='r', linestyle='--')
# Etiquetas de los ejes
plt.xlabel('EPOCH')
plt.ylabel('O-C')

# Título
plt.title('Gráfico de dispersión')

# Mostrar el gráfico
plt.show()
